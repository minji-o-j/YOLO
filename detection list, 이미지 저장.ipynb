# %%
import time

# %% [markdown]
# # pretrained O
# ---
# ## 1. Animal Crossing - 2124 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/animal_crossing.mp4' --save_video_name='animal_crossing' # --export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='animal_crossing', use_cuda=True, video_path='images/animal_crossing.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021185, FPS: 47
# 2 : im detect, cost time 0.006498, FPS: 153
# 3 : im detect, cost time 0.006574, FPS: 152
# 4 : im detect, cost time 0.006471, FPS: 154
# 5 : im detect, cost time 0.006731, FPS: 148
# 6 : im detect, cost time 0.006609, FPS: 151
# 7 : im detect, cost time 0.006975, FPS: 143
# 8 : im detect, cost time 0.006554, FPS: 152
# 9 : im detect, cost time 0.006580, FPS: 151
# 10 : im detect, cost time 0.006580, FPS: 151
# 11 : im detect, cost time 0.006539, FPS: 152
# 12 : im detect, cost time 0.006566, FPS: 152
# 13 : im detect, cost time 0.006575, FPS: 152
# 14 : im detect, cost time 0.006537, FPS: 152
# 15 : im detect, cost time 0.006537, FPS: 152
# ...

# %% [markdown]
# ## 2. Gangstar New Orleans -1437 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/Gangstar.mp4' --save_video_name='Gangstar' #--export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='Gangstar', use_cuda=True, video_path='images/Gangstar.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022763, FPS: 43
# 2 : im detect, cost time 0.008104, FPS: 123
# 3 : im detect, cost time 0.007776, FPS: 128
# 4 : im detect, cost time 0.007375, FPS: 135
# 5 : im detect, cost time 0.007922, FPS: 126
# 6 : im detect, cost time 0.007696, FPS: 129
# 7 : im detect, cost time 0.006829, FPS: 146
# 8 : im detect, cost time 0.007180, FPS: 139
# 9 : im detect, cost time 0.007097, FPS: 140
# 10 : im detect, cost time 0.007162, FPS: 139
# 11 : im detect, cost time 0.007365, FPS: 135
# 12 : im detect, cost time 0.007213, FPS: 138
# 13 : im detect, cost time 0.007338, FPS: 136
# 14 : im detect, cost time 0.007151, FPS: 139
# 15 : im detect, cost time 0.007234, FPS: 138
# 16 : im detect, cost time 0.007215, FPS: 138
# ...

# %% [markdown]
# ## 3. asphalt 8 - 1141 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/asphalt_8.mp4' --save_video_name='asphalt_8' #--export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='asphalt_8', use_cuda=True, video_path='images/asphalt_8.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022048, FPS: 45
# 2 : im detect, cost time 0.007425, FPS: 134
# 3 : im detect, cost time 0.007466, FPS: 133
# 4 : im detect, cost time 0.007268, FPS: 137
# 5 : im detect, cost time 0.007176, FPS: 139
# 6 : im detect, cost time 0.007140, FPS: 140
# 7 : im detect, cost time 0.007198, FPS: 138
# 8 : im detect, cost time 0.007191, FPS: 139
# 9 : im detect, cost time 0.007123, FPS: 140
# 10 : im detect, cost time 0.007187, FPS: 139
# 11 : im detect, cost time 0.007531, FPS: 132
# 12 : im detect, cost time 0.007439, FPS: 134
# 13 : im detect, cost time 0.007299, FPS: 136
# 14 : im detect, cost time 0.007152, FPS: 139
# 15 : im detect, cost time 0.007192, FPS: 139
# 16 : im detect, cost time 0.007272, FPS: 137
# ...

# %% [markdown]
# ## 4. sims 4 - 1825 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/sims_4.mp4' --save_video_name='sims_4' #--export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='sims_4', use_cuda=True, video_path='images/sims_4.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021099, FPS: 47
# 2 : im detect, cost time 0.006486, FPS: 154
# 3 : im detect, cost time 0.006439, FPS: 155
# 4 : im detect, cost time 0.006514, FPS: 153
# 5 : im detect, cost time 0.006467, FPS: 154
# 6 : im detect, cost time 0.006911, FPS: 144
# 7 : im detect, cost time 0.006513, FPS: 153
# 8 : im detect, cost time 0.006459, FPS: 154
# 9 : im detect, cost time 0.006584, FPS: 151
# 10 : im detect, cost time 0.006598, FPS: 151
# 11 : im detect, cost time 0.006534, FPS: 153
# 12 : im detect, cost time 0.006492, FPS: 154
# 13 : im detect, cost time 0.006504, FPS: 153
# 14 : im detect, cost time 0.006482, FPS: 154
# 15 : im detect, cost time 0.006510, FPS: 153
# 16 : im detect, cost time 0.006525, FPS: 153
# ...

# %% [markdown]
# ## 5. FIFA20 - 2439 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/FIFA20.mp4' --save_video_name='FIFA20' #--export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='FIFA20', use_cuda=True, video_path='images/FIFA20.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022650, FPS: 44
# 2 : im detect, cost time 0.007560, FPS: 132
# 3 : im detect, cost time 0.007577, FPS: 131
# 4 : im detect, cost time 0.008220, FPS: 121
# 5 : im detect, cost time 0.007462, FPS: 134
# 6 : im detect, cost time 0.007872, FPS: 127
# 7 : im detect, cost time 0.008081, FPS: 123
# 8 : im detect, cost time 0.007842, FPS: 127
# 9 : im detect, cost time 0.007757, FPS: 128
# 10 : im detect, cost time 0.007486, FPS: 133
# 11 : im detect, cost time 0.007459, FPS: 134
# 12 : im detect, cost time 0.007947, FPS: 125
# 13 : im detect, cost time 0.007677, FPS: 130
# 14 : im detect, cost time 0.007546, FPS: 132
# 15 : im detect, cost time 0.007494, FPS: 133
# 16 : im detect, cost time 0.007565, FPS: 132
# ...

# %% [markdown]
# ## 6. 7days to die - 1010 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/7days_to_die.mp4' --save_video_name='7td' #--export_video_frame=True 
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='7td', use_cuda=True, video_path='images/7days_to_die.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022649, FPS: 44
# 2 : im detect, cost time 0.007436, FPS: 134
# 3 : im detect, cost time 0.007656, FPS: 130
# 4 : im detect, cost time 0.007573, FPS: 132
# 5 : im detect, cost time 0.007850, FPS: 127
# 6 : im detect, cost time 0.007431, FPS: 134
# 7 : im detect, cost time 0.007949, FPS: 125
# 8 : im detect, cost time 0.007902, FPS: 126
# 9 : im detect, cost time 0.007341, FPS: 136
# 10 : im detect, cost time 0.007555, FPS: 132
# 11 : im detect, cost time 0.007748, FPS: 129
# 12 : im detect, cost time 0.007948, FPS: 125
# 13 : im detect, cost time 0.007413, FPS: 134
# 14 : im detect, cost time 0.007309, FPS: 136
# 15 : im detect, cost time 0.007632, FPS: 131
# 16 : im detect, cost time 0.007201, FPS: 138
# ...

# %% [markdown]
# ## 7. Doraemon Story of Seasons - 1393 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/Doraemon_Story_of_Seasons.mp4' --save_video_name='doraemon' # --export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='doraemon', use_cuda=True, video_path='images/Doraemon_Story_of_Seasons.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021144, FPS: 47
# 2 : im detect, cost time 0.006480, FPS: 154
# 3 : im detect, cost time 0.006464, FPS: 154
# 4 : im detect, cost time 0.007003, FPS: 142
# 5 : im detect, cost time 0.007004, FPS: 142
# 6 : im detect, cost time 0.006466, FPS: 154
# 7 : im detect, cost time 0.006766, FPS: 147
# 8 : im detect, cost time 0.006715, FPS: 148
# 9 : im detect, cost time 0.006484, FPS: 154
# 10 : im detect, cost time 0.006466, FPS: 154
# 11 : im detect, cost time 0.007512, FPS: 133
# 12 : im detect, cost time 0.007437, FPS: 134
# 13 : im detect, cost time 0.007124, FPS: 140
# 14 : im detect, cost time 0.007128, FPS: 140
# 15 : im detect, cost time 0.006964, FPS: 143
# ...

# %% [markdown]
# ## 8. left 4 to dead 2 - 1436 Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/left_4_dead_2.mp4' --save_video_name='l4d2' --export_video_frame=True
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=True, model_name='yolov2_epoch_160', output_dir='output', save_video_name='l4d2', use_cuda=True, video_path='images/left_4_dead_2.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# frame: 1436
# 1 : im detect, cost time 0.029148, FPS: 34
# 2 : im detect, cost time 0.006817, FPS: 146
# 3 : im detect, cost time 0.006773, FPS: 147
# 4 : im detect, cost time 0.006446, FPS: 155
# 5 : im detect, cost time 0.006484, FPS: 154
# 6 : im detect, cost time 0.006463, FPS: 154
# 7 : im detect, cost time 0.006511, FPS: 153
# 8 : im detect, cost time 0.006964, FPS: 143
# 9 : im detect, cost time 0.006699, FPS: 149
# 10 : im detect, cost time 0.006533, FPS: 153
# 11 : im detect, cost time 0.006591, FPS: 151
# 12 : im detect, cost time 0.006752, FPS: 148
# 13 : im detect, cost time 0.006501, FPS: 153
# ...

# %% [markdown]
# ## - test Frames

# %%
start = time.time()
# !python3 video_saveframe.py --cuda True --model_name='yolov2_epoch_160' --video_path='images/7days_to_die.mp4' --save_video_name='7td'
print("\n\n--- time :", time.time() - start)
# Out:
# call with args: Namespace(export_video_frame=False, model_name='yolov2_epoch_160', output_dir='output', save_video_name='7td', use_cuda=True, video_path='images/7days_to_die.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022677, FPS: 44
# [[798, 630, 1203, 1052], [843, 497, 1110, 821]]
# 2 : im detect, cost time 0.007508, FPS: 133
# [[843, 495, 1113, 822]]
# 3 : im detect, cost time 0.007503, FPS: 133
# [[802, 620, 1174, 985], [847, 513, 1111, 877]]
# ^C
# Traceback (most recent call last):
#   File "/home/minji/.local/lib/python3.6/site-packages/PIL/ImageFile.py", line 506, in _save
#     fh = fp.fileno()
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "video_saveframe.py", line 265, in <module>
#     demo()
#   File "video_saveframe.py", line 182, in demo
# ...
