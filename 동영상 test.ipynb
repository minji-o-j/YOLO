# %% [markdown]
# # Image Test

# %%
# !python demo.py --cuda true
# Out:
# call with args: Namespace(model_name='yolov2_epoch_160', output_dir='output', use_cuda=True)
# loaded
# model loaded
# im detect, cost time 0.022438, FPS: 44
# Figure(640x480)
# im detect, cost time 0.009815, FPS: 101
# Figure(640x480)

# %% [markdown]
# # Make expanded Videos

# %% [markdown]
# ### FIFA - 2439

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/FIFA20.mp4' #--export_video_frame=True
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', use_cuda=True, video_path='images/FIFA20.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 1 : im detect, cost time 0.022438, FPS: 44
# 2 : im detect, cost time 0.007517, FPS: 133
# 3 : im detect, cost time 0.007578, FPS: 131
# 4 : im detect, cost time 0.006975, FPS: 143
# 5 : im detect, cost time 0.007753, FPS: 128
# 6 : im detect, cost time 0.010818, FPS: 92
# 7 : im detect, cost time 0.006996, FPS: 142
# 8 : im detect, cost time 0.007696, FPS: 129
# 9 : im detect, cost time 0.007617, FPS: 131
# 10 : im detect, cost time 0.006976, FPS: 143
# 11 : im detect, cost time 0.007609, FPS: 131
# 12 : im detect, cost time 0.007677, FPS: 130
# 13 : im detect, cost time 0.007977, FPS: 125
# 14 : im detect, cost time 0.007602, FPS: 131
# 15 : im detect, cost time 0.007629, FPS: 131
# 16 : im detect, cost time 0.007638, FPS: 130
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/FIFA20.mp4' --save_video_name='FIFA20'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='FIFA20', use_cuda=True, video_path='images/FIFA20.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022431, FPS: 44
# 2 : im detect, cost time 0.007535, FPS: 132
# 3 : im detect, cost time 0.007825, FPS: 127
# 4 : im detect, cost time 0.007483, FPS: 133
# 5 : im detect, cost time 0.007502, FPS: 133
# 6 : im detect, cost time 0.007552, FPS: 132
# 7 : im detect, cost time 0.007519, FPS: 133
# 8 : im detect, cost time 0.007521, FPS: 132
# 9 : im detect, cost time 0.007492, FPS: 133
# 10 : im detect, cost time 0.007602, FPS: 131
# 11 : im detect, cost time 0.007743, FPS: 129
# 12 : im detect, cost time 0.007478, FPS: 133
# 13 : im detect, cost time 0.007780, FPS: 128
# 14 : im detect, cost time 0.007519, FPS: 133
# 15 : im detect, cost time 0.007344, FPS: 136
# ...

# %% [markdown]
# ### Gangstar New
