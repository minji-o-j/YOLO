# %% [markdown]
# # Image Test

# %%
# !python demo.py --cuda true
# Out:
# call with args: Namespace(model_name='yolov2_epoch_160', output_dir='output', use_cuda=True)
# loaded
# model loaded
# im detect, cost time 0.022438, FPS: 44
# Figure(640x480)
# im detect, cost time 0.009815, FPS: 101
# Figure(640x480)

# %% [markdown]
# # Make expanded Videos

# %% [markdown]
# ### Gangstar New -1437 frame

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/Gangstar.mp4' --export_video_frame=True --save_video_name='Gangstar'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='Gangstar', use_cuda=True, video_path='images/Gangstar.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# frame: 1437
# 1 : im detect, cost time 0.025049, FPS: 39
# 2 : im detect, cost time 0.007117, FPS: 140
# 3 : im detect, cost time 0.006492, FPS: 154
# 4 : im detect, cost time 0.007521, FPS: 132
# 5 : im detect, cost time 0.007160, FPS: 139
# 6 : im detect, cost time 0.007258, FPS: 137
# 7 : im detect, cost time 0.007223, FPS: 138
# 8 : im detect, cost time 0.007222, FPS: 138
# 9 : im detect, cost time 0.007198, FPS: 138
# 10 : im detect, cost time 0.007147, FPS: 139
# 11 : im detect, cost time 0.006493, FPS: 154
# 12 : im detect, cost time 0.007166, FPS: 139
# 13 : im detect, cost time 0.007225, FPS: 138
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/Gangstar.mp4' --save_video_name='Gangstar'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='Gangstar', use_cuda=True, video_path='images/Gangstar.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022469, FPS: 44
# 2 : im detect, cost time 0.007918, FPS: 126
# 3 : im detect, cost time 0.007646, FPS: 130
# 4 : im detect, cost time 0.008055, FPS: 124
# 5 : im detect, cost time 0.007590, FPS: 131
# 6 : im detect, cost time 0.007620, FPS: 131
# 7 : im detect, cost time 0.007313, FPS: 136
# 8 : im detect, cost time 0.007171, FPS: 139
# 9 : im detect, cost time 0.007157, FPS: 139
# 10 : im detect, cost time 0.007155, FPS: 139
# 11 : im detect, cost time 0.007177, FPS: 139
# 12 : im detect, cost time 0.007346, FPS: 136
# 13 : im detect, cost time 0.007170, FPS: 139
# 14 : im detect, cost time 0.007170, FPS: 139
# 15 : im detect, cost time 0.007148, FPS: 139
# ...

# %% [markdown]
# ### Animal Crossing -2124

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/animal_crossing.mp4' --export_video_frame=True --save_video_name='animal_crossing'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='animal_crossing', use_cuda=True, video_path='images/animal_crossing.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# frame: 2124
# 1 : im detect, cost time 0.020311, FPS: 49
# 2 : im detect, cost time 0.006423, FPS: 155
# 3 : im detect, cost time 0.006483, FPS: 154
# 4 : im detect, cost time 0.006497, FPS: 153
# 5 : im detect, cost time 0.006348, FPS: 157
# 6 : im detect, cost time 0.006773, FPS: 147
# 7 : im detect, cost time 0.006433, FPS: 155
# 8 : im detect, cost time 0.006716, FPS: 148
# 9 : im detect, cost time 0.006240, FPS: 160
# 10 : im detect, cost time 0.006531, FPS: 153
# 11 : im detect, cost time 0.006507, FPS: 153
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/animal_crossing.mp4' --save_video_name='animal_crossing'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='animal_crossing', use_cuda=True, video_path='images/animal_crossing.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021060, FPS: 47
# 2 : im detect, cost time 0.006351, FPS: 157
# 3 : im detect, cost time 0.007128, FPS: 140
# 4 : im detect, cost time 0.006851, FPS: 145
# 5 : im detect, cost time 0.006532, FPS: 153
# 6 : im detect, cost time 0.006452, FPS: 154
# 7 : im detect, cost time 0.006439, FPS: 155
# 8 : im detect, cost time 0.006429, FPS: 155
# 9 : im detect, cost time 0.006749, FPS: 148
# 10 : im detect, cost time 0.006489, FPS: 154
# 11 : im detect, cost time 0.006514, FPS: 153
# 12 : im detect, cost time 0.006559, FPS: 152
# 13 : im detect, cost time 0.006592, FPS: 151
# 14 : im detect, cost time 0.006634, FPS: 150
# 15 : im detect, cost time 0.006540, FPS: 152
# ...

# %% [markdown]
# ### asphalt_8 -1141

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/asphalt_8.mp4' --export_video_frame=True --save_video_name='asphalt_8'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='asphalt_8', use_cuda=True, video_path='images/asphalt_8.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# frame: 1141
# 1 : im detect, cost time 0.021862, FPS: 45
# 2 : im detect, cost time 0.007679, FPS: 130
# 3 : im detect, cost time 0.007397, FPS: 135
# 4 : im detect, cost time 0.011903, FPS: 84
# 5 : im detect, cost time 0.007554, FPS: 132
# 6 : im detect, cost time 0.007849, FPS: 127
# 7 : im detect, cost time 0.007847, FPS: 127
# 8 : im detect, cost time 0.007852, FPS: 127
# 9 : im detect, cost time 0.007442, FPS: 134
# 10 : im detect, cost time 0.007411, FPS: 134
# 11 : im detect, cost time 0.007678, FPS: 130
# 12 : im detect, cost time 0.007151, FPS: 139
# 13 : im detect, cost time 0.007467, FPS: 133
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/asphalt_8.mp4' --save_video_name='asphalt_8'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='asphalt_8', use_cuda=True, video_path='images/asphalt_8.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021961, FPS: 45
# 2 : im detect, cost time 0.007159, FPS: 139
# 3 : im detect, cost time 0.007139, FPS: 140
# 4 : im detect, cost time 0.007164, FPS: 139
# 5 : im detect, cost time 0.007128, FPS: 140
# 6 : im detect, cost time 0.007192, FPS: 139
# 7 : im detect, cost time 0.007613, FPS: 131
# 8 : im detect, cost time 0.007166, FPS: 139
# 9 : im detect, cost time 0.007152, FPS: 139
# 10 : im detect, cost time 0.007349, FPS: 136
# 11 : im detect, cost time 0.007175, FPS: 139
# 12 : im detect, cost time 0.007529, FPS: 132
# 13 : im detect, cost time 0.006868, FPS: 145
# 14 : im detect, cost time 0.007610, FPS: 131
# 15 : im detect, cost time 0.007174, FPS: 139
# ...

# %% [markdown]
# ### sims4 -1825

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/sims_4.mp4' --export_video_frame=True --save_video_name='sims_4'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='sims_4', use_cuda=True, video_path='images/sims_4.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# frame: 1825
# 1 : im detect, cost time 0.022427, FPS: 44
# 2 : im detect, cost time 0.007200, FPS: 138
# 3 : im detect, cost time 0.007666, FPS: 130
# 4 : im detect, cost time 0.007597, FPS: 131
# 5 : im detect, cost time 0.007148, FPS: 139
# 6 : im detect, cost time 0.007332, FPS: 136
# 7 : im detect, cost time 0.007244, FPS: 138
# 8 : im detect, cost time 0.007187, FPS: 139
# 9 : im detect, cost time 0.007175, FPS: 139
# 10 : im detect, cost time 0.007151, FPS: 139
# 11 : im detect, cost time 0.007149, FPS: 139
# 12 : im detect, cost time 0.008861, FPS: 112
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/sims_4.mp4' --save_video_name='sims_4'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='sims_4', use_cuda=True, video_path='images/sims_4.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.020978, FPS: 47
# 2 : im detect, cost time 0.006443, FPS: 155
# 3 : im detect, cost time 0.006409, FPS: 156
# 4 : im detect, cost time 0.006282, FPS: 159
# 5 : im detect, cost time 0.006253, FPS: 159
# 6 : im detect, cost time 0.006210, FPS: 161
# 7 : im detect, cost time 0.006867, FPS: 145
# 8 : im detect, cost time 0.006491, FPS: 154
# 9 : im detect, cost time 0.006521, FPS: 153
# 10 : im detect, cost time 0.006576, FPS: 152
# 11 : im detect, cost time 0.006901, FPS: 144
# 12 : im detect, cost time 0.006761, FPS: 147
# 13 : im detect, cost time 0.006528, FPS: 153
# 14 : im detect, cost time 0.006395, FPS: 156
# 15 : im detect, cost time 0.006610, FPS: 151
# ...

# %% [markdown]
# ### left 4 to dead 2 -1436

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/left_4_dead_2.mp4' --export_video_frame=True --save_video_name='l4d2'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='l4d2', use_cuda=True, video_path='images/left_4_dead_2.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# frame: 1436
# 1 : im detect, cost time 0.020921, FPS: 47
# 2 : im detect, cost time 0.006410, FPS: 156
# 3 : im detect, cost time 0.006684, FPS: 149
# 4 : im detect, cost time 0.006708, FPS: 149
# 5 : im detect, cost time 0.006987, FPS: 143
# 6 : im detect, cost time 0.006724, FPS: 148
# 7 : im detect, cost time 0.006884, FPS: 145
# 8 : im detect, cost time 0.006507, FPS: 153
# 9 : im detect, cost time 0.006482, FPS: 154
# 10 : im detect, cost time 0.006482, FPS: 154
# 11 : im detect, cost time 0.006758, FPS: 147
# 12 : im detect, cost time 0.006452, FPS: 154
# 13 : im detect, cost time 0.006490, FPS: 154
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/left_4_dead_2.mp4' --save_video_name='l4d2'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='l4d2', use_cuda=True, video_path='images/left_4_dead_2.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021020, FPS: 47
# 2 : im detect, cost time 0.006876, FPS: 145
# 3 : im detect, cost time 0.006777, FPS: 147
# 4 : im detect, cost time 0.006470, FPS: 154
# 5 : im detect, cost time 0.006456, FPS: 154
# 6 : im detect, cost time 0.006806, FPS: 146
# 7 : im detect, cost time 0.006440, FPS: 155
# 8 : im detect, cost time 0.006846, FPS: 146
# 9 : im detect, cost time 0.006459, FPS: 154
# 10 : im detect, cost time 0.006950, FPS: 143
# 11 : im detect, cost time 0.006271, FPS: 159
# 12 : im detect, cost time 0.006687, FPS: 149
# 13 : im detect, cost time 0.006482, FPS: 154
# 14 : im detect, cost time 0.006831, FPS: 146
# 15 : im detect, cost time 0.006461, FPS: 154
# ...

# %% [markdown]
# ### 7days to die -1010

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/7days_to_die.mp4' --export_video_frame=True --save_video_name='7td'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='7td', use_cuda=True, video_path='images/7days_to_die.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# frame: 1010
# 1 : im detect, cost time 0.021795, FPS: 45
# 2 : im detect, cost time 0.007300, FPS: 136
# 3 : im detect, cost time 0.007448, FPS: 134
# 4 : im detect, cost time 0.007186, FPS: 139
# 5 : im detect, cost time 0.007348, FPS: 136
# 6 : im detect, cost time 0.007173, FPS: 139
# 7 : im detect, cost time 0.007187, FPS: 139
# 8 : im detect, cost time 0.007747, FPS: 129
# 9 : im detect, cost time 0.006559, FPS: 152
# 10 : im detect, cost time 0.007184, FPS: 139
# 11 : im detect, cost time 0.007289, FPS: 137
# 12 : im detect, cost time 0.007161, FPS: 139
# 13 : im detect, cost time 0.006683, FPS: 149
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/7days_to_die.mp4' --save_video_name='7td'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='7td', use_cuda=True, video_path='images/7days_to_die.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022567, FPS: 44
# 2 : im detect, cost time 0.007518, FPS: 133
# 3 : im detect, cost time 0.007114, FPS: 140
# 4 : im detect, cost time 0.007728, FPS: 129
# 5 : im detect, cost time 0.007989, FPS: 125
# 6 : im detect, cost time 0.007473, FPS: 133
# 7 : im detect, cost time 0.007687, FPS: 130
# 8 : im detect, cost time 0.008116, FPS: 123
# 9 : im detect, cost time 0.007602, FPS: 131
# 10 : im detect, cost time 0.007688, FPS: 130
# 11 : im detect, cost time 0.007717, FPS: 129
# 12 : im detect, cost time 0.008022, FPS: 124
# 13 : im detect, cost time 0.007355, FPS: 135
# 14 : im detect, cost time 0.007427, FPS: 134
# 15 : im detect, cost time 0.007890, FPS: 126
# ...

# %% [markdown]
# ### Doraemon Story of Seasons -1393

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/Doraemon_Story_of_Seasons.mp4' --export_video_frame=True --save_video_name='doraemon'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='doraemon', use_cuda=True, video_path='images/Doraemon_Story_of_Seasons.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# frame: 1393
# 1 : im detect, cost time 0.020822, FPS: 48
# 2 : im detect, cost time 0.006794, FPS: 147
# 3 : im detect, cost time 0.006478, FPS: 154
# 4 : im detect, cost time 0.006234, FPS: 160
# 5 : im detect, cost time 0.009123, FPS: 109
# 6 : im detect, cost time 0.006682, FPS: 149
# 7 : im detect, cost time 0.006405, FPS: 156
# 8 : im detect, cost time 0.006733, FPS: 148
# 9 : im detect, cost time 0.006648, FPS: 150
# 10 : im detect, cost time 0.006476, FPS: 154
# 11 : im detect, cost time 0.006801, FPS: 147
# 12 : im detect, cost time 0.006539, FPS: 152
# 13 : im detect, cost time 0.006432, FPS: 155
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/Doraemon_Story_of_Seasons.mp4' --save_video_name='doraemon'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='doraemon', use_cuda=True, video_path='images/Doraemon_Story_of_Seasons.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.020636, FPS: 48
# 2 : im detect, cost time 0.006486, FPS: 154
# 3 : im detect, cost time 0.006439, FPS: 155
# 4 : im detect, cost time 0.006489, FPS: 154
# 5 : im detect, cost time 0.006493, FPS: 154
# 6 : im detect, cost time 0.006506, FPS: 153
# 7 : im detect, cost time 0.006791, FPS: 147
# 8 : im detect, cost time 0.006462, FPS: 154
# 9 : im detect, cost time 0.006480, FPS: 154
# 10 : im detect, cost time 0.006486, FPS: 154
# 11 : im detect, cost time 0.007758, FPS: 128
# 12 : im detect, cost time 0.007140, FPS: 140
# 13 : im detect, cost time 0.007181, FPS: 139
# 14 : im detect, cost time 0.007429, FPS: 134
# 15 : im detect, cost time 0.006397, FPS: 156
# ...

# %% [markdown]
# ### real 01(동네)) -1895

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/seoul.mp4' --export_video_frame=True --save_video_name='seoul01'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='seoul01', use_cuda=True, video_path='images/seoul.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# frame: 1895
# 1 : im detect, cost time 0.021955, FPS: 45
# 2 : im detect, cost time 0.007561, FPS: 132
# 3 : im detect, cost time 0.007626, FPS: 131
# 4 : im detect, cost time 0.007598, FPS: 131
# 5 : im detect, cost time 0.007713, FPS: 129
# 6 : im detect, cost time 0.007544, FPS: 132
# 7 : im detect, cost time 0.007509, FPS: 133
# 8 : im detect, cost time 0.007623, FPS: 131
# 9 : im detect, cost time 0.007600, FPS: 131
# 10 : im detect, cost time 0.007562, FPS: 132
# 11 : im detect, cost time 0.007026, FPS: 142
# 12 : im detect, cost time 0.007577, FPS: 131
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/seoul.mp4' --save_video_name='seoul01'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='seoul01', use_cuda=True, video_path='images/seoul.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.022569, FPS: 44
# 2 : im detect, cost time 0.007518, FPS: 133
# 3 : im detect, cost time 0.007580, FPS: 131
# 4 : im detect, cost time 0.007759, FPS: 128
# 5 : im detect, cost time 0.007519, FPS: 133
# 6 : im detect, cost time 0.007749, FPS: 129
# 7 : im detect, cost time 0.008246, FPS: 121
# 8 : im detect, cost time 0.007448, FPS: 134
# 9 : im detect, cost time 0.007794, FPS: 128
# 10 : im detect, cost time 0.008027, FPS: 124
# 11 : im detect, cost time 0.007704, FPS: 129
# 12 : im detect, cost time 0.007534, FPS: 132
# 13 : im detect, cost time 0.007489, FPS: 133
# 14 : im detect, cost time 0.007553, FPS: 132
# 15 : im detect, cost time 0.007526, FPS: 132
# ...

# %% [markdown]
# ### real 02(동네)) -2260

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_x160' --video_path='images/seoul02.mp4' --export_video_frame=True --save_video_name='seoul02'
# Out:
# call with args: Namespace(export_video_frame=True, image_folder='images/setframe', model_name='yolov2_epoch_x160', output_dir='output', save_video_name='seoul02', use_cuda=True, video_path='images/seoul02.mp4')
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# frame: 2260
# 1 : im detect, cost time 0.021181, FPS: 47
# 2 : im detect, cost time 0.006657, FPS: 150
# 3 : im detect, cost time 0.006911, FPS: 144
# 4 : im detect, cost time 0.006471, FPS: 154
# 5 : im detect, cost time 0.006485, FPS: 154
# 6 : im detect, cost time 0.006768, FPS: 147
# 7 : im detect, cost time 0.006474, FPS: 154
# 8 : im detect, cost time 0.006811, FPS: 146
# 9 : im detect, cost time 0.006741, FPS: 148
# 10 : im detect, cost time 0.006460, FPS: 154
# 11 : im detect, cost time 0.006805, FPS: 146
# 12 : im detect, cost time 0.006428, FPS: 155
# ...

# %%
# !python3 video_test.py --cuda true --model_name='yolov2_epoch_160'  --video_path='images/seoul02.mp4' --save_video_name='seoul02'
# Out:
# call with args: Namespace(export_video_frame=False, image_folder='images/setframe', model_name='yolov2_epoch_160', output_dir='output', save_video_name='seoul02', use_cuda=True, video_path='images/seoul02.mp4')
# loading model from output/yolov2_epoch_160.pth
# model loaded
# 1 : im detect, cost time 0.021185, FPS: 47
# 2 : im detect, cost time 0.006547, FPS: 152
# 3 : im detect, cost time 0.006531, FPS: 153
# 4 : im detect, cost time 0.006588, FPS: 151
# 5 : im detect, cost time 0.006454, FPS: 154
# 6 : im detect, cost time 0.006508, FPS: 153
# 7 : im detect, cost time 0.006253, FPS: 159
# 8 : im detect, cost time 0.006590, FPS: 151
# 9 : im detect, cost time 0.006562, FPS: 152
# 10 : im detect, cost time 0.006489, FPS: 154
# 11 : im detect, cost time 0.007526, FPS: 132
# 12 : im detect, cost time 0.007570, FPS: 132
# 13 : im detect, cost time 0.007186, FPS: 139
# 14 : im detect, cost time 0.007213, FPS: 138
# 15 : im detect, cost time 0.007228, FPS: 138
# ...
