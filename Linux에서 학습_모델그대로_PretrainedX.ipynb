# %% [markdown]
# # train

# %%
import time
start=time.time()
# !python3 train_new.py --cuda true --mGPUs true
print(time.time()-start)
# Out:
# Called with args:
# Namespace(batch_size=16, checkpoint_epoch=160, dataset='voc0712trainval', decay_lrs={60: 1e-05, 90: 1e-06}, display_interval=10, exp_name='default', lr=0.0001, mGPUs=True, max_epochs=160, momentum=0.9, num_workers=8, output_dir='output', resume=False, save_interval=20, start_epoch=1, use_cuda=True, use_tfboard=False, weight_decay=0.0005)
# loading dataset....
# voc_2007_trainval gt roidb loaded from /home/minji/pt2/yolov2.pytorch/data/cache/voc_2007_trainval_gt_roidb.pkl
# load dataset voc_2007_trainval
# voc_2012_trainval gt roidb loaded from /home/minji/pt2/yolov2.pytorch/data/cache/voc_2012_trainval_gt_roidb.pkl
# load and add dataset voc_2012_trainval
# dataset loaded.
# training rois number: 16551
# initialize the model
# model loaded: cost time 0.63s
# change scale range to (3, 4)
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=663 error=11 : invalid argument
# ...

# %% [markdown]
# ### train: 약 9.1시간 소요
#
# ---
# ---
#
# # test

# %%
start=time.time()
# !python3 test_new.py --cuda true
print(time.time()-start)
# Out:
# Called with args:
# Namespace(batch_size=2, conf_thresh=0.005, dataset='voc07test', model_name='yolov2_epoch_x160', nms_thresh=0.45, num_workers=1, output_dir='output', use_cuda=True, vis=False)
# voc_2007_test gt roidb loaded from /home/minji/pt2/yolov2.pytorch/data/cache/voc_2007_test_gt_roidb.pkl
# loading model from output/yolov2_epoch_x160.pth
# model loaded
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=663 error=11 : invalid argument
# im detect [1/4952]
# im detect [2/4952]
# im detect [3/4952]
# im detect [4/4952]
# im detect [5/4952]
# im detect [6/4952]
# im detect [7/4952]
# im detect [8/4952]
# im detect [9/4952]
# im detect [10/4952]
# im detect [11/4952]
# im detect [12/4952]
# im detect [13/4952]
# im detect [14/4952]
# im detect [15/4952]
# im detect [16/4952]
# im detect [17/4952]
# im detect [18/4952]
# im detect [19/4952]
# im detect [20/4952]
# im detect [21/4952]
# im detect [22/4952]
# im detect [23/4952]
# im detect [24/4952]
# ...

# %% [markdown]
# ### test: 약 3분 26초 소요
